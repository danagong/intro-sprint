# %%
import pandas as pd
import matplotlib.pyplot as plt
# x = [65, 5, 118, 86, 120, 85, 105,90, 70, 117,100 ,74, 100, 100, 187, 119,75, 90, 97, 93, 108, 121]

# %%
x = pd.DataFrame(
    [65, 5, 118, 86, 120, 85, 105,90, 70, 117,100 ,74, 100, 100, 187, 119,75, 90, 97, 93, 108, 121],
    columns = ['Fuzzy Pom Poms'])
hist = x.hist(bins=10, grid = False)
plt.axvline(149, color='purple', linestyle='dashed', linewidth=1)

# %%
y = pd.DataFrame([19,15, 30,36, 15, 20, 18, 15, 12, 15, 40, 15, 28, 24, 19, 57, 33, 25, 31,20, 120], 
                 columns = ['Ring Pops'])
hist = y.hist(bins =10, grid = False)
plt.axvline(12, color='purple', linestyle='dashed', linewidth=1)
